# %%
import numpy as np
import pandas as pd
import os
import os.path as osp

# %%
import sleep_networks.proj_info as info

# %%
sub_list = info.sub_list

# %%
for sbj,run in tqdm(scan_list[1]):
    _,_,sID,_,rID,_,aID = run.split('-')
    scan_folder = '_scan_id_ses-{sID}_task-rest_acq-{aID}_run-{rID}_bold'.format(sID=sID,rID=rID,aID=aID)
    aux_path = osp.join(DATA_DIR,sbj,'preprocessed','func','pb07_qpp',scan_folder)
    if not osp.exists(aux_path):
        os.makedirs(aux_path)

# %%
var = '123'
test = (f'test that this works {var} well')
test
# Out:
# 'test that this works 123 well'

# %%
PRJ_DIR = '/project/mdrosenberg/IG/Flanker_onesub'
OUTPUT_DIR= osp.join(PRJ_DIR, 'derivatives')
PREPROC_DIR= osp.join(PRJ_DIR, 'preprocessed')
fd_thresh=0.5 #TODO: check w prepreg
TR = 2

#Subjects:
#TODO: write sub_list
sub = 'sub-01'
ses = 'ses-01'

prep_img = osp.join(OUTPUT_DIR,sub,sub,'func',sub+'_task-flanker_run-1_space-MNI152NLin2009cAsym_res-2_desc-preproc_bold.nii.gz')
print('Image: ', prep_img)
# brain mask
prep_mask_img = osp.join(OUTPUT_DIR,sub,sub,'func',sub+'_task-flanker_run-1_space-MNI152NLin2009cAsym_res-2_desc-brain_mask.nii.gz')
print('Mask: ', prep_mask_img)
# Out:
# Image:  /project/mdrosenberg/IG/Flanker_onesub/derivatives/sub-01/sub-01/func/sub-01_task-flanker_run-1_space-MNI152NLin2009cAsym_res-2_desc-preproc_bold.nii.gz
# Mask:  /project/mdrosenberg/IG/Flanker_onesub/derivatives/sub-01/sub-01/func/sub-01_task-flanker_run-1_space-MNI152NLin2009cAsym_res-2_desc-brain_mask.nii.gz

# %%
out_file = '1_'+sub+'_task-flanker_fmriprep_output.nii.gz'
out_path = osp.join(PREPROC_DIR,sub,out_file)
if osp.exists(out_path):
    print('Masking already complete: ', out_path)
else:
    run_masking = (f'3dcalc -a {prep_img} -b {prep_mask_img} -expr "(a*b)" -prefix {out_path}')
    #os.system(run_masking)
    print('File written: ', out_path)
# Out:
# File written:  /project/mdrosenberg/IG/Flanker_onesub/preprocessed/sub-01/1_sub-01_task-flanker_fmriprep_output.nii.gz

# %%
run_masking
# Out:
# '3dcalc -a /project/mdrosenberg/IG/Flanker_onesub/derivatives/sub-01/sub-01/func/sub-01_task-flanker_run-1_space-MNI152NLin2009cAsym_res-2_desc-preproc_bold.nii.gz -b /project/mdrosenberg/IG/Flanker_onesub/derivatives/sub-01/sub-01/func/sub-01_task-flanker_run-1_space-MNI152NLin2009cAsym_res-2_desc-brain_mask.nii.gz -expr "(a*b)" -prefix /project/mdrosenberg/IG/Flanker_onesub/preprocessed/sub-01/1_sub-01_task-flanker_fmriprep_output.nii.gz'

# %%
3dcalc -a /project/mdrosenberg/IG/Flanker_onesub/derivatives/sub-01/sub-01/func/sub-01_task-flanker_run-1_space-MNI152NLin2009cAsym_res-2_desc-preproc_bold.nii.gz -b /project/mdrosenberg/IG/Flanker_onesub/derivatives/sub-01/sub-01/func/sub-01_task-flanker_run-1_space-MNI152NLin2009cAsym_res-2_desc-brain_mask.nii.gz -expr "(a*b)" -prefix /project/mdrosenberg/IG/Flanker_onesub/preprocessed/sub-01/1_sub-01_task-flanker_fmriprep_output.nii.gz

# %%
out_file = '2_'+sub+'_task-flanker_intensity_normalization.nii.gz'
out_path = osp.join(PREPROC_DIR,sub,out_file)
if osp.exists(out_path):
    print('Intensity norm already complete: ', out_path)
else:
    run_in = (f'fslmaths {PREPROC_DIR}/1_{sub}_task-flanker_fmriprep_output.nii.gz -inm 10000 {out_file}')
    #os.system(run_in)
    print('File written: ', out_file)
# Out:
# File written:  2_sub-01_task-flanker_intensity_normalization.nii.gz

# %%
run_in
# Out:
# 'fslmaths /project/mdrosenberg/IG/Flanker_onesub/preprocessed/1_sub-01_task-flanker_fmriprep_output.nii.gz -inm 10000 2_sub-01_task-flanker_intensity_normalization.nii.gz'

# %%
PRJ_DIR = '/project/mdrosenberg/IG/Flanker_onesub'
sub = 'sub-01'

# %%
OUTPUT_DIR= osp.join(PRJ_DIR, 'derivatives')
# preprocessed output directory
PREPROC_DIR= osp.join(PRJ_DIR, 'preprocessed')

# preprocessed, MNI-registered EPI
prep_img = osp.join(OUTPUT_DIR,sub,sub,'func',sub+'_task-flanker_run-1_space-MNI152NLin2009cAsym_res-2_desc-preproc_bold.nii.gz')
print('Image: ', prep_img)
# brain mask
prep_mask_img = osp.join(OUTPUT_DIR,sub,sub,'func',sub+'_task-flanker_run-1_space-MNI152NLin2009cAsym_res-2_desc-brain_mask.nii.gz')
print('Mask: ', prep_mask_img)

# ------------ #
print('1. Mask fMRIprep output')
out_file = '1_'+sub+'_task-flanker_fmriprep_output.nii.gz'
out_path = osp.join(PREPROC_DIR,sub,out_file)
# Out:
# Image:  /project/mdrosenberg/IG/Flanker_onesub/derivatives/sub-01/sub-01/func/sub-01_task-flanker_run-1_space-MNI152NLin2009cAsym_res-2_desc-preproc_bold.nii.gz
# Mask:  /project/mdrosenberg/IG/Flanker_onesub/derivatives/sub-01/sub-01/func/sub-01_task-flanker_run-1_space-MNI152NLin2009cAsym_res-2_desc-brain_mask.nii.gz
# 1. Mask fMRIprep output

# %%
run_masking = (f'3dcalc -a {prep_img} -b {prep_mask_img} -expr "(a*b)" -prefix {out_path}')

# %%
run_masking
# Out:
# '3dcalc -a /project/mdrosenberg/IG/Flanker_onesub/derivatives/sub-01/sub-01/func/sub-01_task-flanker_run-1_space-MNI152NLin2009cAsym_res-2_desc-preproc_bold.nii.gz -b /project/mdrosenberg/IG/Flanker_onesub/derivatives/sub-01/sub-01/func/sub-01_task-flanker_run-1_space-MNI152NLin2009cAsym_res-2_desc-brain_mask.nii.gz -expr "(a*b)" -prefix /project/mdrosenberg/IG/Flanker_onesub/preprocessed/sub-01/1_sub-01_task-flanker_fmriprep_output.nii.gz'

# %%
out_path
# Out:
# '/project/mdrosenberg/IG/Flanker_onesub/preprocessed/sub-01/1_sub-01_task-flanker_fmriprep_output.nii.gz'
