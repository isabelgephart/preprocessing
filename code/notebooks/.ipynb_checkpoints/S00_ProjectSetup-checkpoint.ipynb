# %% [markdown]
# # This notebook is the first step in preprocessing an fMRI dataset
#
# ## It does the following:
# * Installs custom functions from package
# * Create folder structure for project

# %% [markdown]
# Note: currently preprocessing package not set up, 1 is wrong
# # 1. Install package
#
# ### 1. If you cloned the preprocessing repo from github, you should have the following files: setup.py, ***
# ### 2. Go to the code folder for this project and type
# ``` bash
# pip install .
# ```
# ### on the command line
#
# ### 3. Test that this worked by running the cell below, if you do not get an error then you should be good

# %%
import sleep_networks.proj_info as info

# %% [markdown]
# # 2. Folder structure
#
# ## SELECT PROJECT NAME:

# %%
PRJ = 'preproc_test_bball'

# %%
import os.path as osp
import os

# %%
PRJ_DIR = osp.join('/project/mdrosenberg/IG', PRJ)

# %%
#PRJ_DIR
if not osp.exists(PRJ_DIR):
    os.makedirs(PRJ_DIR)
    print('Created directory: ', PRJ_DIR)
else:
    print('Directory exists: ', PRJ_DIR)

#CODE_DIR
c = osp.join(PRJ_DIR, 'code')
if not osp.exists(c):
    os.makedirs(c)
    print('Created directory: ', c)
else:
    print('Directory exists: ', c)

# #notebooks
# n = osp.join(CODE_DIR,'notebooks')
# if not osp.exists(n):
#     os.makedirs(n)
#     print('Created directory: ', n)
# else:
#     print('Directory exists: ', n)

# #bash
# b = osp.join(CODE_DIR,'bash')
# if not osp.exists(b):
#     os.makedirs(b)
#     print('Created directory: ', b)
# else:
#     print('Directory exists: ', b)

# #python
# p = osp.join(CODE_DIR,'python')
# if not osp.exists(p):
#     os.makedirs(p)
#     print('Created directory: ', p)
# else:
#     print('Directory exists: ', p)

#SBATCH
s = osp.join(c,'SBATCH')
if not osp.exists(s):
    os.makedirs(s)
    print('Created directory: ', s)
else:
    print('Directory exists: ', s)

#derivatives
f = osp.join(PRJ_DIR,'fmriprep')
if not osp.exists(f):
    os.makedirs(f)
    print('Created directory: ', f)
else:
    print('Directory exists: ', f)

#work
w = osp.join(PRJ_DIR,'work')
if not osp.exists(w):
    os.makedirs(w)
    print('Created directory: ', w)
else:
    print('Directory exists: ', w)

#preprocessed
p = osp.join(PRJ_DIR,'preprocessed')
if not osp.exists(p):
    os.makedirs(p)
    print('Created directory: ', p)
else:
    print('Directory exists: ', p)
# Out:
# Directory exists:  /project/mdrosenberg/IG/preproc_test_bball
# Directory exists:  /project/mdrosenberg/IG/preproc_test_bball/code
# Directory exists:  /project/mdrosenberg/IG/preproc_test_bball/code/SBATCH
# Created directory:  /project/mdrosenberg/IG/preproc_test_bball/fmriprep
# Created directory:  /project/mdrosenberg/IG/preproc_test_bball/work
# Created directory:  /project/mdrosenberg/IG/preproc_test_bball/preprocessed

# %% [markdown]
# ### The setup is now done.
