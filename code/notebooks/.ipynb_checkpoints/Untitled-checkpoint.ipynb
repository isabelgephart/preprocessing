# %%
PREPROC_DIR = '/project/mdrosenberg/IG/preproc_test_bball/derivatives/preprocessed'
prefix = 'sub-01_ses-01_task-view_run-01_'

# %%
import os.path as osp
import os

# %%
out_file = 'shen_2mm_2mm_2_75mm_268_parcellation_resampled+tlrc'
if not osp.exists(osp.join(PREPROC_DIR, out_file)):
    cmd = '3dresample -master ' + PREPROC_DIR+'/3_'+prefix+'nuissance_regressed.nii.gz' + ' -prefix ' + PREPROC_DIR + '/' + out_file + ' -inset /project/mdrosenberg/IG/preprocessing/atlases/shen_2mm_268_parcellation.nii.gz' + ' -rmode NN'
    os.system(cmd)
    print('Resampling complete: ', out_file)
else:
    print('Resampling already complete: ', out_file)
# Out:
# 3dresample -master/project/mdrosenberg/IG/preproc_test_bball/derivatives/preprocessed/3_sub-01_ses-01_task-view_run-01_nuissance_regressed.nii.gz-prefix /project/mdrosenberg/IG/preproc_test_bball/derivatives/preprocessed/shen_2mm_2mm_2_75mm_268_parcellation_resampled+tlrc -inset /project/mdrosenberg/IG/preprocessing/atlases/shen_2mm_268_parcellation.nii.gz-rmode NN
# Resampling complete:  shen_2mm_2mm_2_75mm_268_parcellation_resampled+tlrc
